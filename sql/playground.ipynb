# %%
import pandas as pd
import duckdb

# %%
# %%sql
# select * from processed_transactions where account_
# Out:
#     id                            account_id          transaction_id  amount  \
# 0  153  6236a826-b352-4696-83ad-7cb1f8be1556  PAY_P_A1UQMHUSD3D71113       5
# 1  154  6236a826-b352-4696-83ad-7cb1f8be1556  PAY_P_A1UQWD94KF171112       5
#
#                     timestamp   status                     created_at  \
# 0  2025-07-20 11:24:27.619+00  SUCCESS  2025-07-20 11:30:14.882347+00
# 1  2025-07-20 21:29:04.792+00  SUCCESS  2025-07-20 21:30:15.508924+00
#
#                                             metadata            type
# 0  {"order_type": "C2C", "wallet_type": 2, "conta...  PAY_WITHDRAWAL
# 1  {"order_type": "C2C", "wallet_type": 2, "conta...  PAY_WITHDRAWAL

# %%
# %%sql
#     select
#         amount, account_name, timestamp
#
#
# FROM processed_transactions
#   JOIN binance_accounts ON processed_transactions.account_id = binance_accounts.id
#   WHERE binance_accounts.account_name = 'ondra_osobni_sub_acc1';
# Out:
#       amount           account_name               timestamp
# 0    5.00000  ondra_osobni_sub_acc1  2025-08-04 12:46:53+00
# 1    5.00000  ondra_osobni_sub_acc1  2025-08-04 12:02:28+00
# 2    5.00000  ondra_osobni_sub_acc1  2025-08-04 11:40:10+00
# 3   35.00000  ondra_osobni_sub_acc1  2025-08-04 11:39:58+00
# 4    5.00000  ondra_osobni_sub_acc1  2025-08-04 10:58:43+00
# 5    5.00000  ondra_osobni_sub_acc1  2025-08-04 10:38:10+00
# 6   10.00000  ondra_osobni_sub_acc1  2025-08-04 10:15:49+00
# 7    5.00000  ondra_osobni_sub_acc1  2025-08-03 21:44:10+00
# 8    5.00000  ondra_osobni_sub_acc1  2025-08-03 20:12:38+00
# 9   10.00000  ondra_osobni_sub_acc1  2025-08-03 20:11:21+00
# 10  10.00000  ondra_osobni_sub_acc1  2025-08-03 19:54:51+00
# 11  10.00000  ondra_osobni_sub_acc1  2025-08-03 18:30:48+00
# 12  10.00000  ondra_osobni_sub_acc1  2025-08-03 18:29:08+00
# 13  10.00000  ondra_osobni_sub_acc1  2025-08-03 16:11:12+00
# 14   5.00000  ondra_osobni_sub_acc1  2025-08-03 16:02:14+00
# ...

# %%
# %%sql
# select *
# from nav_history
# where account_name = 'ondra_osobni_sub_acc1'
# ORDER BY created_at DESC          -- nebo id DESC
# LIMIT 100;
# Out:
#      id           account_name                            account_id  \
# 0  5984  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 1  5880  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 2  5875  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 3  5870  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 4  5865  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 5  5860  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 6  5855  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 7  5850  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
# 8  5848  ondra_osobni_sub_acc1  657dd8b7-bfc3-4ccc-a899-ba8ce648d203
#
#                        timestamp  nav  benchmark_value  btc_price  eth_price  \
# 0  2025-08-11 14:30:08.812796+00   15         0.000000  119904.90    4289.14
# 1  2025-08-04 21:02:07.686268+00   20        43.089707  114848.56    3702.97
# ...

# %%
# %%sql
